# %%
print ("hello world i am yann")
# Out:
# hello world i am yann

# %%
#lets go learning python
#ceci est un commentaire dans la cellule de code
#python est une programmation oriente OBJET. On def des variables
name= "yann"
print(name)
# Out:
# yann

# %%
#pour les chiffres on a
age=23
print(age)
# Out:
# 23

# %%
#a dictionnary is a CLE VALEUR

prices = (
    "AAPL":248.04,
    "GOOGLE")
